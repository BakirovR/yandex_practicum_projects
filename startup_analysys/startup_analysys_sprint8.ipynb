# %% [markdown]
# # Исследование заведений общественного питания Москвы

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Нулевые-значения-колонки-number" data-toc-modified-id="Нулевые-значения-колонки-number-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Нулевые значения колонки number</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Пропуски-значений" data-toc-modified-id="Пропуски-значений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пропуски значений</a></span></li><li><span><a href="#Сокращение-названий--типов-объекта-общественного-питания" data-toc-modified-id="Сокращение-названий--типов-объекта-общественного-питания-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Сокращение названий  типов объекта общественного питания</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ--данных" data-toc-modified-id="Анализ--данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ  данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-соотношения-видов-объектов-общественного-питания-по-количеству" data-toc-modified-id="Анализ-соотношения-видов-объектов-общественного-питания-по-количеству-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ соотношения видов объектов общественного питания по количеству</a></span></li><li><span><a href="#Анализ-соотношения-сетевых-и-несетевых-заведений-по-количеству." data-toc-modified-id="Анализ-соотношения-сетевых-и-несетевых-заведений-по-количеству.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ соотношения сетевых и несетевых заведений по количеству.</a></span></li><li><span><a href="#Анализ--сетевых-заведений" data-toc-modified-id="Анализ--сетевых-заведений-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ  сетевых заведений</a></span></li><li><span><a href="#Определение-среднего--количества-посадочных-мест-для-каждого-вида-объекта-общественного-питания" data-toc-modified-id="Определение-среднего--количества-посадочных-мест-для-каждого-вида-объекта-общественного-питания-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Определение среднего  количества посадочных мест для каждого вида объекта общественного питания</a></span></li><li><span><a href="#Построение-графика-топ-10-улиц-по-количеству-объектов-общественного-питания" data-toc-modified-id="Построение-графика-топ-10-улиц-по-количеству-объектов-общественного-питания-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построение графика топ-10 улиц по количеству объектов общественного питания</a></span></li><li><span><a href="#Определение-числа-улиц-с-одним-объектом-общественного-питания." data-toc-modified-id="Определение-числа-улиц-с-одним-объектом-общественного-питания.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Определение числа улиц с одним объектом общественного питания.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-презентации" data-toc-modified-id="Подготовка-презентации-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка презентации</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта**
#
# Мы решили открыть небольшое кафе в Москве. Оно оригинальное — гостей должны обслуживать роботы. Проект многообещающий, но дорогой. Вместе с партнёрами мы решились обратиться к инвесторам. Их интересует текущее положение дел на рынке — сможем ли мы снискать популярность на долгое время, когда все зеваки насмотрятся на роботов-официантов?
#
#
# **Цель исследования** — осуществить анализ рынка заведений общественного питания в Москве.
#
# **Ход исследования**
#
# У нас есть открытые данные о заведениях общественного питания в Москве.
#
#
# Данные о заведениях мы  получим из файла `rest_data.csv`.
#
#
# О качестве данных ничего не известно. Поэтому перед проведением исследования понадобится обзор данных.
#
# Мы проверим данные на ошибки и оценим их влияние на исследование. Затем на этапе предобработки мы поищем возможность исправить самые критичные из них.
#
# Таким образом, исследование пройдёт в четыре этапа:
#
#
#  1. Изучение данных;
#  2. Предобработка данных;
#  3. Анализ данных;
#  4. Подготовка презентации.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Составим первое представление о заведениях общественного питания Москвы.

# %% [markdown]
# Импортируем  библиотеки `pandas, numpy, matplotlib, seaborn, datetime, io, requests`.

# %%
# импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from io import BytesIO
import requests
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Прочитаем файл `rest_data.csv` из папки `/datasets` и сохраним его в переменной `df`.

# %%
# чтение файла с данными и сохранение в df
try:
    df = pd.read_csv('/datasets/rest_data.csv')

except:
    df = pd.read_csv(
        'D:\\Аналитик данных\\Яндекс-практикум\\Sprint8\\rest_data.csv')

# %% [markdown]
# Выведим на экран первые пять строк таблицы.

# %%
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# Получим общую информацию о таблице с помощью метода info().

# %%
# вывод общей информации о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
#  2   chain        15366 non-null  object
#  3   object_type  15366 non-null  object
#  4   address      15366 non-null  object
#  5   number       15366 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB

# %% [markdown]
# Изучим значения столбца number, используя метод describe().

# %%
# применение метода describe() к столбцу
df['number'].describe()
# Out:
# count    15366.000000
# mean        59.547182
# std         74.736833
# min          0.000000
# 25%         12.000000
# 50%         40.000000
# 75%         80.000000
# max       1700.000000
# Name: number, dtype: float64

# %% [markdown]
# Посмотрим на уникальные значения в каждом столбце. Для этого напишем функцию `data_unique` и применим её к датафрейму.

# %%
# функция определения уникальных значений столбцов
def data_unique(data):
    for column in data.columns:
        print('Уникальные значения столбца', column)
        print(data[column].unique())

# %%
# применение функции к датафрейму
data_unique(df)
# Out:
# Уникальные значения столбца id
# [151635  77874  24309 ... 209186 221900 222535]
# Уникальные значения столбца object_name
# ['СМЕТАНА' 'Родник' 'Кафе «Академия»' ... 'Бар Мята Lounge'
#  'Мята Lounge Октябрьская' 'Кальянная «Мята Lounge»']
# Уникальные значения столбца chain
# ['нет' 'да']
# Уникальные значения столбца object_type
# ['кафе' 'столовая' 'закусочная' 'предприятие быстрого обслуживания'
#  'ресторан' 'кафетерий' 'буфет' 'бар' 'магазин (отдел кулинарии)']
# Уникальные значения столбца address
# ['город Москва, улица Егора Абакумова, дом 9'
#  'город Москва, улица Талалихина, дом 2/1, корпус 1'
#  'город Москва, Абельмановская улица, дом 6' ...
#  'город Москва, Салтыковская улица, дом 7Г'
#  'город Москва, Осенний бульвар, дом 9'
#  'город Москва, улица Новый Арбат, дом 13']
# Уникальные значения столбца number
# [  48   35   95   40   50  240   10   90  150  120    5   24  140   32
#   270  320    7    2  160   20   30  110    6  192   65   45    4  125
# ...

# %% [markdown]
# Итак:
#
# *  В таблице df шесть столбцов;
# *  Тип данных: `object, int`;
# *  Категориальные переменные в столбцах: `object_name, chain, object_type, address`;
# * Количественные переменные в столбцах: `id, number`;
# * Количество наблюдений: 15366.
#
# Согласно документации к данным.
#
# Структура df:
#
# - id — идентификатор объекта;
# - object_name — название объекта общественного питания;
# - chain — сетевой ресторан;
# - object_type — тип объекта общественного питания;
# - address — адрес;
# - number — количество посадочных мест.
#
# В значениях столбца  `number` встречаются нулевые значения. Рассмотрим их подробнее.
#
# Проверим данные на строки-дубликаты и пропуски значений.

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблице информация  о заведениях общественного питания в Москве.
#
# Предварительно можно утверждать: данных достаточно для проведения исследования.
#
# Чтобы двигаться дальше, нужно осуществить предобработку.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Рассмотрим нулевые значения в столбце  `number` . Затем проверим данные на дубликаты и пропуски значений.
# Осуществим сокращение названий столбца `object_type`.

# %% [markdown]
# ### Нулевые значения колонки number

# %% [markdown]
# Выведем на экран 10 строк таблицы df, в которых значения в столбце `number` равно 0.

# %%
# вывод строк таблицы df
df.query('number == 0').head(10)
# Out:
#          id         object_name chain                        object_type  \
# 137  115498     Пекарня & Донер   нет                         закусочная
# 154  152556       Шаурма в пите   нет  предприятие быстрого обслуживания
# 157  149568                Суши   нет  предприятие быстрого обслуживания
# 190  126956  Шаурма, куры-гриль   нет  предприятие быстрого обслуживания
# 195  149531  Шаурма, куры-гриль   нет  предприятие быстрого обслуживания
# 198  124201     Шаурма, выпечка   нет  предприятие быстрого обслуживания
# 206  150836    ГБОУ Школа №1468   нет                           столовая
# 219  156226            Суши-шоп   нет                         закусочная
# 240  154738             Пекарня   нет  предприятие быстрого обслуживания
# 278   25742              БИСТРО   нет  предприятие быстрого обслуживания
#
#                                                address  number
# 137     город Москва, Бутырская улица, дом 9, корпус 2       0
# ...

# %% [markdown]
# Посмотрим на кол-во объектов разного типа.

# %%
df.query('number == 0')['object_type'].value_counts()
# Out:
# предприятие быстрого обслуживания    704
# кафе                                 310
# закусочная                           189
# магазин (отдел кулинарии)            145
# кафетерий                            113
# буфет                                 68
# ресторан                              45
# бар                                   28
# столовая                              19
# Name: object_type, dtype: int64

# %% [markdown]
# Найдем процент нулевых значений в столбце `number`.

# %%
# подсчет % нулевых значений
(df.query('number == 0')['number'].count() / df['number'].count()) * 100
# Out:
# 10.549264610178316

# %% [markdown]
# Таким образом кол-во нулевых значений сооставляет порядка: 10.5%. Удаление данных значений или замена медианой может значительно повлиять на результаты. Наиболее вероятно, что в данных объектах питания действительно отсутствуют посадочные места, оставим данные без изменения.

# %% [markdown]
# Осуществим проверку таблицы на дубликаты.

# %% [markdown]
# ###  Проверка на дубликаты

# %% [markdown]
# Отметим, что значения в колонке `object_name` представлены строчными и прописными буквами. Приведем всё к нижнему регистру.

# %%
# перевод значений в столбце к нижнему регистру
df['object_name'] = df['object_name'].apply(lambda x: x.lower())
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# Посчитаем явные дубликаты в таблице одной командой.

# %%
# подсчёт явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим данные на неявные дубликаты. Рассмотрим значения столбца `object_name`.

# %%
# вывод уникальных значений столбца

lst = df['object_name'].unique().tolist()
print(sorted(lst))
# Out:
# ['1-й мок', '1-ый московский кадетский корпус', '100 личная столовая', '100 личное кафе', '1001 ночь', '100лоффка', '101 вкус', '13 rules', '13 rules kraft beer', '15 kitchen+bar', '18 автобусный парк', '19bar atmosphere', '1x bet', '2-й автобусный парк', "23'00", '24 градуса', '259', '3 skovorodki', '3 правила', '33 пингвина', '37-37', '44 чашма', '495', '5звезд юг 52', '68. пауза', '69 pints', '69 pints бар', '7 злаков', '7 сендвичей', '7 сэндвичей-meating', '7717 lounge (кальянная)', '8 oz унций', '8-ой троллейбусный парк', '9 автобусный парк', '9bar', 'abbey players irish pub', 'abc coffee roasters', 'absolem', 'acai family', 'accenti', 'adry', 'aglomerat', 'al33 пиццерия бар ботега', 'alex пекарня', 'aloha poke bar', 'amande cafe', 'amarsi', 'americano кафе', 'amerigos pizza', 'amg', 'amore grande', 'amore, итальянское мороженое', 'amster bar snacks', 'an nam', 'andiamo', "andy's friends", 'apartament пар бар', 'aqkitchen', 'arahis pub', 'arbat hall', 'arena by soho family', 'ar
# ...

# %% [markdown]
# Итак, в данных есть одни и те же значения, которые записаны разными языками и способами, к примеру,`'burger king' - 'burgerking'`  Помимо этого, в данных есть подозрительное кол-во значений: "веранда". Последовательно разберемся в ситуации. Создадим словарь синонимов и выпишем все совпадения.

# %%
# создание словаря синонимов
synonyms = {
    'kfc': ['fridays kfc', 'kfc волгоградский', 'kfc.', 'закусочная kfc', 'закусочная «kfc»',
            'кафе kfc', 'кафе «kfc»', 'кфс амрест', 'пбо «kfc покрышкина»', 'пбо «kfc»',
            'предприятие быстрого обслуживания «kfc»', 'ресторан kfc', 'ресторан «kfc»',
            'ресторан быстрого питания kfc', 'ресторан кфс', 'ростикс kfc'],
    'burger king': ['burgerking', 'бурген кинг', 'бургер кинг', 'бургер кинг burger king',
                    'закусочная «бургер кинг»', 'кафе «бургер кинг»', 'кафе бургер кинг',
                    'кафе-закусочная «бургер кинг»',
                    'предприятие быстрого обслуживания «бургер кинг»', 'ресторан «бургер кинг»'],
    'mcdonalds': ['кафе «макдоналдс»', 'кафе макдоналдс', 'макдоналдс', 'москва - макдоналдс',
                  'предприятие быстрого обслуживания «макдоналдс»', 'ресторан «макдоналдс»', 'ресторан«макдоналдс»'],
    'bb&burgers': ['bb & burgers', 'bb энд burger', 'бб энд бургерс в&в бургер'],
    'burger club': ['бургер клаб'],
    'coffeeshop company': ['кофешоп coffeeshop company'],
    'cofix': ['кофикс'],
    'costa coffee': ['кафе «costa coffee»', 'кафе коста', 'коста кофе', 'кофейня «costa coffee»', 'кофейня кофе коста'],
    'dunkin donuts': ['dunkin donuts (азия box - бургер box)', 'данкин донатс', 'кафе dunkin donuts',
                      'кафе «данкин донатс»'],
    'florentini': ['ресторан «florentini»', 'флорентини'],
    'fridays': ['фрайдис'],
    'glowsubs sandwiches': ['glow sabs', 'глоу сабс'],
    'goodman': ['goodman гудман', 'гудман', 'гудман гудвин', 'ресторан «goodman»', 'ресторан гудман',
                'стейк хаус гудман', 'стейк-хаус гудман'],
    'grand урюк': ['гранд урюк'],
    'healthy food': ['кафе «healthy food»'],
    'il forno': ['il forno иль форно', 'альфорно', 'иль форно'],
    'jeffreys coffee': ['джеффрис кофе'],
    'krispy kreme': ['krispy creme', 'krispy krem'],
    'lavkalavka': ['кафе «лавкалавка»', 'лавкалавка'],
    'maki maki': ['маки-маки', 'ресторан маки-маки', 'ресторан японской кухни «маки-маки»',
                  'суши «маки-маки»', 'суши бар «маки-маки»'],
    'moskalyan': ['анти-кафе кальянная «moskalyan»', 'кальян-бар moskalyan',
                  'кальянная «москальян»', 'кафе «кальянная москальян»', 'москальян'],
    'movenpick': ['coffee & waffles & movenpick', 'коктейли movenpick', 'мороженное movenpick'],
    'osteria mario': ['bq cafe & osteria mario', 'osteria mario+швили', 'osteriamario', 'остериа марио',
                      'остерия марио', 'ресторан «osteria mario»'],
    'paul': ['paul cafe', 'paul поль',
             'кафе «поль бейкери»', 'кафе-пекарня paul',
             'поль бейкери', 'ресторан paul'],
    'prime star': ['prime star прайм стар', 'prime прайм стар',
                   'prime прайм стар прайм-кафе', 'кафе prime прайм стар', 'кафе prime прайм стар прайм-кафе',
                   'кафе «prime star»', 'кафе «prime» (прайм стар)', 'кафе «prime» прайм стар', 'кафе «прайм стар»',
                   'кафе прайм стар',
                   'прайм стар', 'прайм стар кафе', 'прайм-кафе прайм стар', 'праймкафе прайм стар'],
    'starbucks': ['starbucks coffee', 'starbucks кофе', 'starbucks старбакс', 'starbucks',
                  'старбакс кофе', 'кафе starbucks',
                  'кафе «starbucks»', 'кафе «кофейня старбакс»',
                  'кафе «сабвей» старбакс', 'кафе «старбакс»', 'кофейня «старбакс кофе»', 'кофейня «старбакс»',
                  'кофемания starbucks', 'старбакс', 'старбакс starbucks', 'старбакс кофе'],
    'subway': ['кафе «subway»', 'кафе «сабвэй»', 'кафе сабвей', 'сабвей', 'сабвей subway', 'сабвей сушивок', 'сабвэй'],
    'tgi fridays': ['ресторан tgi friday s', 'ресторан «tgi fridays»'],
    'torro grill': ['torro gril & wine bar',
                    'torro grill & wine bar', 'torro grill торро гриль',
                    'ресторан торро гриль', 'торро гриль'],
    'travelers coffee': ['travelers coffe', "кафе «traveler's coffee»", 'кафе «travelers coffee»',
                         'кофейня тревеллерс'],
    'tutti frutti': ['tutti frutti frozen yogurt', 'кафе мороженного «tutti frutti»', 'тутти фрутти'],
    'upside down cake': ['upside down', 'upside down cake (udcкафе)', 'upside down cake кафе'],
    'vanwok': ['van wok', 'van wok ванвок', 'vanwok ванвок', 'ванвок'],
    'wokker': ['вокер', 'воккер', 'кафе воккер', 'каффе «wokker»'],
    'кулинарная лавка братьев караваевых': ['«кафе «кулинарная лавка братьев караваевых»',
                                            '«кафе «кулинарная лавка братьев караваевых»»',
                                            'братья караваевы', 'братья караваевых',
                                            'кафе «кулинарная лавка братьев караваевых»',
                                            'кулинарная лавка братьев караваевых братья караваевы'],
    'алло пицца': ['алло-пицца', 'пиццерия «алло пицца»'],
    'баскин роббинс': ['закусочная «баскин роббинс & стардогс»', 'кафе «баскин роббинс»'],
    'додо пицца': ['додопицца', 'пицца «додо»', 'пиццерия «додо пицца»', 'пиццерия «додо»',
                   'предприятие быстрого обслуживания «додо пицца»'],
    "domino's pizza": ['domino-s pizza', 'dominos pizza', "домино'с пицца", "домино'с пицца domino,s pizza",
                       'доминос пицца',
                       "кафе «домино'с пицца»", "пиццерия «домино'с пицца»",
                       "предприятие быстрого обслуживания «домино'с пицца»", "ресторан «домино'с пицца»",
                       'ресторан доминос'],
    'крошка картошка': ['закусочная «крошка картошка»', 'кафе «крошка картошка»', 'кафе «крошка-картошка»',
                        'крошка крем', 'крошка-картошка', 'крошкакартошка',
                        'предприятие быстрого обслуживания «крошка картошка»',
                        'предприятие быстрого питания «крошка картошка»',
                        'ресторан быстрого питания «крошка картошка»'],
    'шоколадница': ['кафе «шоколадница»', 'кофейня «шоколадница»', 'кофейня шоколадница', 'шоколадница кофе хаус',
                    'шоколадница кофемания', 'шоколадница экспресс'],
    'теремок': ['закусочная «теремок»', 'кафе «теремок»', 'кафе теремок', 'пбо «теремок»',
                'предприятие быстрого обслуживания «теремок»', 'ресторан «теремок»',
                'ресторан теремок'],
    'суши wok': ['бар «суши wok»', 'кафе «суши wok»', 'кафе суши wok', 'сеть магазинов «суши wok»'],
    'милти': ['готовые блюда милти', 'магазин готовой еды «милти»', 'милти готовые блюда для здорового питания',
              'предприятие быстрого обслуживания «милти»', 'точка продажи готовой еды милти'],
    'папа джонс': ['кафе «папа джонс»', 'папа джойс', 'папа джонс пицца', 'пицерия «папа джонс»',
                   'пицерия папа джонс', 'пиццерия «папа джонс»', 'пиццерия папа джонс'],
    'чайхона №1': ['вlack burger чайхона №1', 'кафе чайхона №1',
                   'павлин мавлин чайхона №1', 'ресторан «чайхона №1»', 'чайхона №1 бутово'],
    'якитория': ['кафе «якитория»', 'кафе якитория', 'ресторан «якитория»', 'якитория и спорт бар',
                 'якитория и ян примус'],
    'кофе хаус': ['кафе «кофе хаус»', 'кофе хаус,экспресс', 'кофе хаус. экспрессо и капучино бар',
                  'кофейня «кофе хаус»'],
    'хлеб насущный': ['кафе «хлеб насущный»', 'кафе хлеб насущный'],
    'тануки': ['кафе «тануки»', 'ресторан «тануки»', 'ресторан тануки'],
    'мята lounge': ['бар мята lounge', 'кальян- бар «мята lounge»', 'кальян-бар «мята lounge»',
                    'кальян-бар мята lounge', 'кальянная «мята lounge»', 'кальянная мята lounge',
                    'кафе «мята lounge» кальянный клуб', 'лаундж-бар «мята lounge»', 'мята lounge автозаводская',
                    'мята lounge октябрьская', 'мята lounge шаболовка'],
    'му-му': ['кафе «му-му»', 'кафе быстрого питания му-му', 'кафе му-му'],
    'pizza hut': [ 'закусочная «пицца хат»', 'кафе «пицца хат»', 'пицца хат',
                  'пиццерия «пицца хат»', 'ресторан «пицца хат»']

}

# %% [markdown]
# Создадим функцию check_synonyms и применим её к датафрейму для замены синонимичных названий.

# %%
# создание функции
def check_synonyms(cell):
    for name, syn in synonyms.items():
        if cell in syn: return name
    return cell

# %%
# применение функции к столбцу 'object_name'
df['object_name'] = df['object_name'].apply(check_synonyms)

# %% [markdown]
# Осуществим проверку.

# %%
df.query('object_name =="mcdonalds"').head()
# Out:
#         id object_name chain                        object_type  \
# 120  26075   mcdonalds    да  предприятие быстрого обслуживания
# 156  26279   mcdonalds    да                               кафе
# 159  22301   mcdonalds    да  предприятие быстрого обслуживания
# 328  26131   mcdonalds    да                           ресторан
# 426  26713   mcdonalds    да                               кафе
#
#                                                address  number
# 120        город Москва, Большая Бронная улица, дом 29     580
# 156           город Москва, Варшавское шоссе, дом 143А      70
# 159   город Москва, улица Маршала Василевского, дом 17      45
# 328  город Москва, Дмитровское шоссе, дом 89, корпус 4      79
# 426  город Москва, Мясницкая улица, дом 30/1/2, стр...     131

# %% [markdown]
# Синонимичные названия заменены. Посмотрим на значения датафрейма, в которых в столбце `object_name` присутствует слово "веранда".

# %%
filt = df['object_name'].str.contains('веранда')
df.loc[filt,:]
# Out:
#            id               object_name chain object_type  \
# 2310   152612       гриль-бар «веранда»   нет    ресторан
# 2535    24621            кафе «веранда»   нет    ресторан
# 4483    26334          ресторан веранда   нет    ресторан
# 8868   156360  ресторан «веранда 32.05»   нет    ресторан
# 9020   162573                   веранда   нет        кафе
# 9148   162674                   веранда   нет        кафе
# 10350  173806                веранда 18   нет    ресторан
# 10351  173809              веранда 17.1   нет    ресторан
# 10352  173815                веранда 17   нет    ресторан
# 10353  173817              веранда 16.1   нет    ресторан
# 10354  173819                веранда 16   нет    ресторан
# 10355  173820              веранда 15.1   нет    ресторан
# 10356  173822                веранда 15   нет    ресторан
# 10761  173641               веранда 1.1   нет    ресторан
# 10762  173642               веранда 3.1   нет    ресторан
# ...

# %% [markdown]
# Название веранды по индексом 12592 впечатляет, но у нас нет оснований удалять данные строки, т.к. они различаются по кол-ву мест. Если взглянуть на яндекс карты, то по адресу:город Москва, Лесная улица, дом 20, действительно, расположено несколько строений.
#
# Проверим данные на дубликаты после внесенных изменений.

# %%
# подсчёт явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты отсутствуют. Исключим из проверки столбец `id` и снова выполним проверку.

# %%
# выделение дублированных строк без столбца id
df.loc[:, ['object_name','chain','object_type','address','number']].duplicated().sum()
# Out:
# 85

# %% [markdown]
# Таким образом, мы обнаружили восемьдесят пять дублированных значений. Осуществим их удаление.

# %%
df.drop_duplicates(subset= ['object_name','chain','object_type','address','number'], inplace=True)

# %% [markdown]
# Выполним проверку.

# %%
df.loc[:, ['object_name','chain','object_type','address','number']].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Теперь дубликаты отсутствуют. Перейдем к подсчету пропущенных значений.

# %% [markdown]
# ### Пропуски значений

# %% [markdown]
# Посчитаем сколько в таблицах пропущенных значений. Для этого достаточно двух методов `pandas`:

# %%
# подсчёт пропущенных значений
df.isna().sum()
# Out:
# id             0
# object_name    0
# chain          0
# object_type    0
# address        0
# number         0
# dtype: int64

# %% [markdown]
# Пропуски отсутствуют.

# %% [markdown]
# ### Сокращение названий  типов объекта общественного питания

# %% [markdown]
# Заменим тип объекта: `предприятие быстрого обслуживания` на `пбо` и `магазин (отдел кулинарии)` - на `кулинария`, чтобы в дальнейшем осуществлять лаконичный вывод названий на графиках. Осуществим замену, используя loc.

# %%
# замена длинных названий
df.loc[df['object_type']=="предприятие быстрого обслуживания", 'object_type'] = 'пбо'
df.loc[df['object_type']=="магазин (отдел кулинарии)", 'object_type'] = 'кулинария'

# %% [markdown]
# Выполним проверку.

# %%
# вывод таблицы df
df.query('object_type =="пбо" or object_type =="кулинария"').tail()
# Out:
#            id object_name chain object_type  \
# 15334  211228       милти    да   кулинария
# 15335  211221       милти    да   кулинария
# 15336  211209       милти    да         пбо
# 15337  208477       милти    да         пбо
# 15338  211201       милти    да   кулинария
#
#                                             address  number
# 15334      город Москва, Дубравная улица, дом 34/29       0
# 15335          город Москва, Пятницкое шоссе, дом 3       0
# 15336       город Москва, Ореховый бульвар, дом 22А       0
# 15337  город Москва, 3-й Крутицкий переулок, дом 18       0
# 15338     город Москва, Новослободская улица, дом 4       0

# %% [markdown]
# Замена выполнена успешно.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Предобработка обнаружила следующие проблемы в данных:
#
# - 10.5% нулевых значений в столбце `number`;
# - 85 дублированных значений.
#
# Наибольшее количеством отсутствующих посадочных мест приходится на предприятия быстрого обслуживания. Заменять такие значения медианными или удалять неправильно, т.к. это может сильно исказить результаты.
#
# Также мы осуществили удаление дублей и сократили длинные названия.
#
# Перейдем к анализу данных.

# %% [markdown]
# ## Анализ  данных

# %% [markdown]
# Исследуем соотношение видов объектов общественного питания по количеству. Построим график.

# %% [markdown]
# ### Анализ соотношения видов объектов общественного питания по количеству

# %% [markdown]
# Найдем количество объектов разных типов, используя сводную таблицу.

# %%
# построение сводной таблицы
report  = df.pivot_table(index='object_type', values='id', aggfunc='count').sort_values(by='id').reset_index()
report.columns = ['object_type', 'number']
report
# Out:
#   object_type  number
# 0   кулинария     273
# 1  закусочная     348
# 2   кафетерий     395
# 3       буфет     576
# 4         бар     855
# 5         пбо    1897
# 6    ресторан    2282
# 7    столовая    2584
# 8        кафе    6071

# %% [markdown]
# Построим столбчатую диаграму, опираясь на сводную таблицу.

# %%
# построение диаграммы
fig, ax = plt.subplots(figsize = (8,8))
ax = sns.barplot(x='object_type', y='number', data=report, ci=None)
plt.title('Cоотношение видов объектов питания по количеству')
plt.xlabel("Тип объекта"), plt.ylabel("Кол-во объектов, шт")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Оценим процентное распределение. Для этого построим круговую диаграмму.

# %%
fig, ax = plt.subplots(figsize = (8,8))
colors = sns.color_palette('pastel')[:9]
ax = plt.pie(report['number'], labels = report['object_type'], autopct='%.0f%%',colors=colors)
plt.title("Процентное распределение объектов питания")
plt.show()

# %% [markdown]
# Таким образом, первое место занимают кафе, за ними расположились столовые, и замыкают тройку лидеров рестораны.

# %% [markdown]
# Исследуем соотношение сетевых и несетевых заведений по количеству. Построим график.

# %% [markdown]
# ### Анализ соотношения сетевых и несетевых заведений по количеству.

# %% [markdown]
# Построим сводную таблицу с разделением по столбцу `chain`.

# %%
# вывод df
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %%
# построение сводной таблицы
report  = df.pivot_table(index='object_type', columns='chain',values='id', aggfunc='count')
report
# Out:
# chain          да   нет
# object_type
# бар            37   818
# буфет          11   565
# закусочная     56   292
# кафе         1396  4675
# кафетерий      52   343
# кулинария      78   195
# пбо           788  1109
# ресторан      543  1739
# столовая        3  2581

# %% [markdown]
# Посмотрим на общее распределение между сетевыми и несетевыми заведениями.
# Для этого построим круговую диаграмму.

# %%
# построение круговой диаграммы
fig, ax = plt.subplots(figsize = (5,5))
colors = sns.color_palette('pastel')[0:2]
ax = plt.pie([report['да'].sum(),report['нет'].sum()],labels = ['сетевые',"несетевые"],  autopct='%.0f%%',colors=colors)
plt.title("Общее распределение между сетевыми и несетевыми заведениями")
plt.show()

# %% [markdown]
# Итак, 81% принадлежит несетевым заведениям и лишь 19% сетевым.

# %% [markdown]
# Построим столбчататые диаграммы для сравнения сетевых и несетевых заведений по типу объекта.

# %%
fig, ax = plt.subplots(figsize = (8,8))
report.plot(kind = 'bar',ax = ax)
plt.title('Cоотношение сетевых и несетевых видов объектов питания по количеству')
plt.xlabel("Тип объекта"), plt.ylabel("Кол-во объектов, шт")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Определим отношение между сетевыми и несетевыми заведениями внутри одной категории.

# %%
report['div'] = round((report['да'] / report['нет']) * 100,2) 
report.sort_values(by = 'div', ascending=False)
# Out:
# chain          да   нет    div
# object_type
# пбо           788  1109  71.06
# кулинария      78   195  40.00
# ресторан      543  1739  31.22
# кафе         1396  4675  29.86
# закусочная     56   292  19.18
# кафетерий      52   343  15.16
# бар            37   818   4.52
# буфет          11   565   1.95
# столовая        3  2581   0.12

# %% [markdown]
# Построим столбчатую диаграмму по столбцу div.

# %%
# построение диаграммы
fig, ax = plt.subplots(figsize = (8,8))
ax = sns.barplot(x=report.index, y='div', data=report, ci=None)
plt.title('Отношение между сетевыми и несетевыми  заведениями \n внутри одной категории')
plt.xlabel("Тип объекта"), plt.ylabel("Отношение")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Таким образом лидирующее место по кол-ву своих сетевых "коллег" занимают предприятия быстрого обслуживания, магазины с отделами кулинарии и рестораны.

# %% [markdown]
# Определим, что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %% [markdown]
# ### Анализ  сетевых заведений

# %% [markdown]
# Отберем только сетевые заведения из датафрейма df.

# %%
# выборка сетевых заведений
report = df.query('chain =="да"')
report.head()
# Out:
#         id object_name chain object_type  \
# 3    21894  пиццетория    да        кафе
# 6   148815    брусника    да        кафе
# 13   22579  алло пицца    да        кафе
# 16  144107    суши wok    да         пбо
# 18   58565      тануки    да    ресторан
#
#                                               address  number
# 3             город Москва, Абрамцевская улица, дом 1      40
# 6       город Москва, переулок Сивцев Вражек, дом 6/2      10
# 13              город Москва, улица Авиаторов, дом 14      32
# 16                город Москва, Азовская улица, дом 3       7
# 18  город Москва, Большая Академическая улица, дом 65     160

# %% [markdown]
# Для каждой сети посчитаем число заведений и среднее число посадочных мест.

# %%
report = df.pivot_table(index=['object_name'], values = 'number', aggfunc = ['count','mean']).reset_index() 
report.columns = ['name','number_restaurant','number_place']
report['number_place'] = report['number_place'].apply(round)
report = report.sort_values(by = ['number_restaurant'], ascending= False)
report.head()
# Out:
#              name  number_restaurant  number_place
# 7401     столовая                321            74
# 3392         кафе                263            28
# 9217       шаурма                241             1
# 615           kfc                192            56
# 9552  шоколадница                189            57

# %% [markdown]
#  Разобъем все сети на 4 группы по признакам много/мало ресторанов, много/мало посадочных мест. Для этого создадим функцию `category` и применим её к датафрейму.

# %%
# Функции для категоризации заведений - кол-ву мест 

def category (row):
    # определение переменных
    number_restaurant = row['number_restaurant']
    number_place = row['number_place']
       
    
    # условия для категоризации
    
    if number_restaurant <= 3 and number_place <= 50:
        return 'Мало заведений - мало мест'
    
    elif number_restaurant > 3 and number_place <= 50:
        return 'Много заведений - мало мест'  
    
    elif number_restaurant <= 3 and number_place > 50:
        return 'Мало заведений - много мест'
    
    return 'Много заведений - много мест'

# %%
# применение функции к датафрейму
report ['category'] = report.apply(category, axis=1)
report.head()
# Out:
#              name  number_restaurant  number_place  \
# 7401     столовая                321            74
# 3392         кафе                263            28
# 9217       шаурма                241             1
# 615           kfc                192            56
# 9552  шоколадница                189            57
#
#                           category
# 7401  Много заведений - много мест
# 3392   Много заведений - мало мест
# 9217   Много заведений - мало мест
# 615   Много заведений - много мест
# 9552  Много заведений - много мест

# %% [markdown]
# Построим график с разбивкой по категориям.

# %%
# построение диаграммы рассеивания
sns.scatterplot(x='number_restaurant', y='number_place', data=report, hue='category',alpha=0.3)
plt.xlim(0,50)
plt.ylim(0,350)
plt.show()

# %% [markdown]
# Оценим кол-во строк в каждой из двух категорий.

# %%
report.query('category=="Много заведений - мало мест"').count()
# Out:
# name                 180
# number_restaurant    180
# number_place         180
# category             180
# dtype: int64

# %%
report.query('category=="Мало заведений - много мест"').count()
# Out:
# name                 3721
# number_restaurant    3721
# number_place         3721
# category             3721
# dtype: int64

# %% [markdown]
# Таким образом, мы можем констатировать, что для сетевых заведений характерно следующее: малое число заведений с большим количеством посадочных мест.

# %% [markdown]
# Для каждого вида объекта общественного питания найдем среднее количество посадочных мест. Определим какой вид предоставляет в среднем самое большое количество посадочных мест. Построим график.

# %% [markdown]
# ### Определение среднего  количества посадочных мест для каждого вида объекта общественного питания

# %%
# вывод таблицы
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# Сгруппируем датафрейм по столбцу `object_type` и найдем среднее количество посадочных мест.

# %%
report = df.groupby(['object_type'])['number'].agg(['mean']).sort_values(by='mean',ascending = False)
report['mean'] = report['mean'].apply(round)
report
# Out:
#              mean
# object_type
# столовая      130
# ресторан       97
# буфет          51
# бар            44
# кафе           40
# пбо            21
# кафетерий       9
# закусочная      8
# кулинария       6

# %% [markdown]
# Построим график boxplot и столбчатую диаграмму для добавления в презентацию.

# %%
# построение графика «ящик с усами» 
fig, ax = plt.subplots(figsize = (15,10))
ax =sns.boxplot(x='object_type', y='number', data=df, palette="Set2")
plt.ylim(0,450)
plt.show()

# %%
# построение диаграммы
fig, ax = plt.subplots(figsize = (8,8))
ax = sns.barplot(x='object_type', y='number', data=df, ci=None)
plt.title('Среднее кол-во посадочных мест по объектам')
plt.xlabel("Тип объекта"), plt.ylabel("Среднее кол-во")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Итак, наибольшее среднее кол-во посадочных мест у столовых. Далее следуют рестораны, буфеты и бары.

# %% [markdown]
# Построим график топ-10 улиц по количеству объектов общественного питания.  Ответим на вопрос: в каких районах Москвы находятся эти улицы?

# %% [markdown]
# ### Построение графика топ-10 улиц по количеству объектов общественного питания

# %% [markdown]
# Выделим в отдельный столбец `street`информацию об улице из столбца address .

# %%
# выделение улицы из адреса
df['street'] = df['address'].apply(lambda x: x.split(',')[1])
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
#
#                    street
# 0   улица Егора Абакумова
# 1        улица Талалихина
# 2    Абельмановская улица
# 3      Абрамцевская улица
# 4      Абрамцевская улица

# %% [markdown]
# Осуществим построение сводной таблицы.

# %%
# построение сводной таблицы
report  = df.pivot_table(index='street',  values='object_type', aggfunc='count').sort_values(by = 'object_type',ascending= False).reset_index()
report.columns = ['street','number_restaurants']
report.head(10)
# Out:
#                     street  number_restaurants
# 0         город Зеленоград                 232
# 1            проспект Мира                 203
# 2        Профсоюзная улица                 181
# 3   Ленинградский проспект                 170
# 4   Пресненская набережная                 167
# 5         Варшавское шоссе                 161
# 6       Ленинский проспект                 147
# 7      поселение Сосенское                 137
# 8     проспект Вернадского                 128
# 9     Кутузовский проспект                 114

# %% [markdown]
# Исключим город Зеленоград из расчетов, а поселение Сосенское будем считать за одну большую улицу.

# %%
report = report.iloc[1:11,:]
report['street'] = report['street'].apply(str.strip)
report
# Out:
#                     street  number_restaurants
# 1            проспект Мира                 203
# 2        Профсоюзная улица                 181
# 3   Ленинградский проспект                 170
# 4   Пресненская набережная                 167
# 5         Варшавское шоссе                 161
# 6       Ленинский проспект                 147
# 7      поселение Сосенское                 137
# 8     проспект Вернадского                 128
# 9     Кутузовский проспект                 114
# 10         Каширское шоссе                 111

# %% [markdown]
# Построим график топ-10 улиц по количеству объектов общественного питания.

# %%
# построение диаграммы
fig, ax = plt.subplots(figsize = (8,8))
ax = sns.barplot(x='number_restaurants', y='street', data=report, ci=None)
plt.title(' Топ-10 улиц по количеству объектов общественного питания')
plt.xlabel("Число объектов"), plt.ylabel("Улица")
plt.show()

# %% [markdown]
# Таким образом, наибольшее кол-во объектов расположено на проспекте Мира. Возможно, большое количество кафе связано с рентабельностью заведений: они окупаются.

# %% [markdown]
# Чтобы определить районы Москвы, через которые проходят улицы. Загрузим внешнюю таблицу df_new.

# %%
# загрузка внешней таблицы
spreadsheet_id = '1CPDYDGjKCb6jGoQt9KR5WOvTspK-dHS3NUrVeqsyqJs'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
df_new = pd.read_csv(BytesIO(r.content))
df_new.columns = ['street','areaid', 'okrug','area']
df_new['street'] = df_new['street'].apply(str.strip)
df_new.head()
# Out:
#                             street  areaid okrug               area
# 0             Выставочный переулок      17   ЦАО  Пресненский район
# 1                     улица Гашека      17   ЦАО  Пресненский район
# 2          Большая Никитская улица      17   ЦАО  Пресненский район
# 3                Глубокий переулок      17   ЦАО  Пресненский район
# 4  Большой Гнездниковский переулок      17   ЦАО  Пресненский район

# %% [markdown]
# Объединим таблицы и посчитаем кол-во районов на каждую улицу.

# %%
# объединение таблиц
report = report.merge(df_new)[['street','area']]
report
# Out:
#                     street                             area
# 0            проспект Мира               Алексеевский район
# 1            проспект Мира                Ярославский Район
# 2            проспект Мира               Район Марьина роща
# 3            проспект Мира               Останкинский район
# 4            проспект Мира                  Район Ростокино
# 5            проспект Мира                   Район Свиблово
# 6            проспект Мира                  Мещанский район
# 7        Профсоюзная улица              Академический район
# 8        Профсоюзная улица                  Район Черемушки
# 9        Профсоюзная улица                    Район Ясенево
# 10       Профсоюзная улица                   Район Коньково
# 11       Профсоюзная улица                Обручевский район
# 12       Профсоюзная улица                Район Теплый Стан
# 13  Ленинградский проспект                   Район Аэропорт
# 14  Ленинградский проспект                    Район Беговой
# ...

# %%
# подсчет кол-ва районов 
report['street'].value_counts()
# Out:
# Варшавское шоссе          8
# Ленинский проспект        8
# проспект Мира             7
# Профсоюзная улица         6
# проспект Вернадского      5
# Ленинградский проспект    4
# Каширское шоссе           4
# Кутузовский проспект      2
# Пресненская набережная    1
# Name: street, dtype: int64

# %% [markdown]
# Таким образом, несмотря на то, что Варшавское шоссе и Ленинский проспект проходят через большее число районов Москвы, количество объектов на этих улицах меньше, чем на проспекте  Мира, Профсоюзной улице и  Ленинградском проспекте.

# %% [markdown]
# Найдем число улиц с одним объектом общественного питания. Определим через какие районы Москвы проходят эти улицы.

# %% [markdown]
# ### Определение числа улиц с одним объектом общественного питания.

# %% [markdown]
# Построим сводную таблицу и выделим все улицы с одним объектом.

# %%
# построение сводной таблицы
report  = df.pivot_table(index='street', values='object_type', aggfunc='count').sort_values(by = 'object_type').reset_index()
report.columns = ['street','number_restaurants']
report=report.query('number_restaurants ==1')
report['street'] = report['street'].apply(str.strip)
report.head()
# Out:
#                 street  number_restaurants
# 0     улица Недорубова                   1
# 1    Театральная аллея                   1
# 2        Таёжная улица                   1
# 3  Газгольдерная улица                   1
# 4     Тарханская улица                   1

# %% [markdown]
# Посчитаем кол-во улиц с одним объектом.

# %%
# подсчет числа улиц
report['street'].count()
# Out:
# 579

# %% [markdown]
# Таким образом, мы обнаружили 579 улиц с одним объектом питания.

# %% [markdown]
# Посчитаем кол-во районов на каждую улицу.

# %%
# объединение таблиц
report = report.merge(df_new)[['street','area']]
report.head()
# Out:
#                 street                    area
# 0    Театральная аллея          Район Аэропорт
# 1        Таёжная улица  Лосиноостровский район
# 2  Газгольдерная улица     Нижегородский район
# 3     Тарханская улица   Район Выхино-Жулебино
# 4      Тарусская улица           Район Ясенево

# %%
# подсчет кол-ва районов 
report['street'].value_counts()
# Out:
# Хавская улица                3
# улица Достоевского           3
# Нарвская улица               3
# 11-я Парковая улица          3
# Перовский проезд             2
#                             ..
# 1-й Голутвинский переулок    1
# 1-й Вешняковский проезд      1
# Канатчиковский проезд        1
# Гранатный переулок           1
# Старомонетный переулок       1
# Name: street, Length: 517, dtype: int64

# %% [markdown]
# Итак, в топ 4 вошли Нарвская улица, Хавская улица, 11-я Парковая улица и улица Достоевского.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы осуществили анализ заведений общественного питания Москвы и можем выйти к инвесторам со следующими предложениями:
#
# - открыть кафе на проспекте Мира в одном из районов;
#
#
# - сделать порядка 40-50 посадочных мест, тем самым сэкономить на аренде помещения и выделиться среди конкурентов при последующем расширении сети;
#
#
# - выполнить дальнейшее расширение сети, т.к. только 29% заведений типа кафе имеют сетевого "коллегу";
#
#
# - расширение сети проводить по районам проспекта Мира, ввиду упрощения логистического сообщения между заведениями.

# %% [markdown]
# ## Подготовка презентации

# %% [markdown]
# Последовательно создадим слайды для презентации, сохраним результат в формате pdf и осуществим загрузку на Google Drive.

# %% [markdown]
# Презентация: <https://drive.google.com/file/d/12FCeqrWYgk0gnhWVAKvAQ4bG0tcaJvUS/view?usp=sharing>
